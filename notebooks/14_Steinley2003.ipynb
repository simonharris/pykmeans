# %%
import imports
import nbutils
from initialisations import steinley2003 as steinley
#from datasets import loader

# %%
#dataset = loader.load_hartigan()
#data = dataset.data
#target = dataset.target # derived from sklearn default K-means

#K = 3

loops = 5000

# %%
#centroids = steinley.generate(data, K, )
#print(centroids)

nbutils.run_clustering(steinley, {'restarts':loops})
# Out:
# Running HART
# ...
#
# SSE is now: 217.0
# SSE is now: 152.25
# SSE is now: 55.4
# SSE is now: 49.75
# SSE is now: 48.33333333333333
# Initial seeds:
# [[ 8.25 28.75  1.  ]
#  [ 7.   30.5   1.5 ]
#  [ 8.5  32.    1.5 ]]
#
# Discovered centroids:
# [[12.         25.66666667  1.        ]
#  [ 6.         30.          1.33333333]
#  [ 5.         36.5         1.5       ]]
#
# Accuracy Score: 1.0
# Adjusted Rand Index: 1.0
# NMI: 1.0
# Inertia: 48.333333333333336
#
#
# Running IRIS
# ...
#
# SSE is now: 680.4120465686275
# SSE is now: 672.3973333333333
# SSE is now: 665.333257456829
# SSE is now: 659.9132200734393
# SSE is now: 643.7036131868132
# SSE is now: 633.1861299271482
# SSE is now: 631.2821409168082
# SSE is now: 608.9542698412698
# SSE is now: 605.4092430773597
# Initial seeds:
# [[5.7754717  3.01698113 3.57924528 1.08490566]
#  [5.97924528 3.08113208 3.97169811 1.28301887]
#  [5.76136364 3.07727273 3.71590909 1.23636364]]
#
# Discovered centroids:
# ...
